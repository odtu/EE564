# %% [markdown]
# #Transformer Design for a HVDC Transmission System#
# The purpose of this project is to design AC / AC transformer for using in HVDC transmission line.
# ***
# Here are some links to ger you familiar with HVDC Transformers:
#
#
# [HVDC Transformer](http://www.electrical-knowhow.com/2012/01/hvdc-transformers.html)
# ***
#
#  (deneme link) unraleted link
#
# [Google](https://www.google.com.tr/)
# ***
# ###Specifications of Transformer
# * **6.5 MVA**,Single Phase transformer,
#
# * Operating Frequency: **500 Hz**
#
#
# * Input Voltage: **3 kV**
#
#
# * Output Voltage:** 300kV**
#
#
# * Operating Temperature **110 °C**

# %%
# Image Downloading Deneme
from IPython.display import Image 
Image(filename='HVDCtransformer.png')

# %%
#Deneme Plotting
x = linspace(0, 5, 10)
y = x ** 2

plot(x, y, 'r')
plot(2*x,9*y,'b')
plot(x**2,y,'g')
xlabel('x')
ylabel('y')
title('deneme plot')
show()

# %% [markdown]
# **Tablo Deneme **
#
# Markdown |Less|Pretty
# ---|---|---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
# A|B|C

# %%
# Mat Deneme 
x=9
y=sqrt(x)*x*2
print y
a=2.14
z=1234.00 /214.0
print (z)
z+5
# Out:
# 54.0
# 5.76635514019
# 10.766355140186917
