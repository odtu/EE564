# %% [markdown]
# #               EE564 Project #2 Tesla Motor Design

# %% [markdown]
# ##Tesla RWD 85 Model Motor Parameters:

# %%
from IPython.display import Image
Image(filename='torquespeed.png')

# %% [markdown]
# Tesla has two motor, rear wheel drives.

# %% [markdown]
# **Max power:** 270kW
#
# **Max torque:** 441 Nm
#
# **Max speed:** 225km/h (car speed)

# %% [markdown]
# **Gear ratio: **1/9.73

# %% [markdown]
# **Wheel diameter (Michelin catalog):**245mm x 0.45 x 2+19”=0.7 m

# %% [markdown]
# **Max speed of the motors:** Nmax:15591 rpm

# %%
import math
pi=3.141592
w=0.7 ; #wheeldiameter from michelin catalog
g=9.73;  #gearratio=9.73
Nmax=225000/(w*pi*60)*g
print Nmax
# Out:
# 16591.9062692

# %% [markdown]
# **Rated Torque:** 300 LB-ft. : 406 Nm

# %% [markdown]
# **Rated speed of the motor:**  665 rad/s

# %% [markdown]
# ##Is it logical about the rated speed for tesla car? (confirmation)

# %%
Wr=665 #rated speed of the motor
Wrrpm= Wr*60/(2*pi) #rpm
Speed=Wrrpm*60/1000*0.7*pi/g #in traffic speed km/h
print Speed
# Out:
# 86.1151079137

# %% [markdown]
# 86 km/h is ideal speed for a car as a rated speed. Checked

# %% [markdown]
# ## Pole Selection

# %% [markdown]
# "For most all traction motors the optimum number of poles = 4 resulting in lowest
# leakage reactance, highest power factor and efficiency"
#
# http://sites.ieee.org/miami/files/2014/11/Hendershot-FIU-Lecture.pdf

# %% [markdown]
# Pole number is selected as a four pole.

# %% [markdown]
# ##Why tesla is so small according to industrial Induction machine?

# %% [markdown]
# 1-	Liquid cooling is used

# %% [markdown]
# 2-High permeability (expensive) electrical steel is used with thinner lamination.

# %% [markdown]
# 3-Cast copper is used on motor. It increasing filling factor and it is lower resistance according to aluminum.

# %% [markdown]
# 4-High input frequency is used. For rated speed and 4 pole machine

# %% [markdown]
# f_rated≅200 hertz             ( calculated from $N_ rpm=\frac{120*f}{p}$)
#
# f_max≅553 hertz

# %% [markdown]
# ##Material Selection

# %%
from IPython.display import Image
Image(filename='electricalsteel.png')
