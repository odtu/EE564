# %% [markdown]
# 2^2

# %%
exp(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0a236a9466c0> in <module>()
# ----> 1 exp(0)
#
# NameError: name 'exp' is not defined

# %%
2+2

# %% [markdown]
# # Introduction
#
# ## frmree
#
# - ddsf
# - dfdsg
#
# $$x^2 = \int$$
#
#     $$\pm 50$$
#
# # Chapter 1
#
# ## Section 1
#
# $$ x^3+x^2+1 \int \pm \alpha \beta \Beta $$
#
# $b_n$

# %%
D=2
L=5
D*L
# Out:
# 10

# %%
D+4
# Out:
# 6

# %% [markdown]
# $$ \int $$

# %% [markdown]
# $\Gamma$
