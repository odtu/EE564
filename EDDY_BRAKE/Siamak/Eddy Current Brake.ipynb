# %% [markdown]
# # Eddy Current Brake System

# %% [markdown]
# #### The project aims to design a Eddy current braking system. Eddy current brakes utilize eddy current produced in a conductive material by a changing magnetic field to generate smooth braking torque in contrast with traditional friction braking.
# #### An eddy current braking system consists of one or more cores or permanent magnet with a small air gap, and a rotating disc with conductive properties. This coil encases a core material which has magnetic properties. The number of turns in the coil is dependent on the desired magnetic field strength and braking force. Eddy currents produce an opposing magnetic field to slow down an object such as a conductive rotating disc. These forces are created by inducing a current through the coil when a disc, with conductive properties rotate within the air gap. The magnitude of these forces is dependent on the conductivity of the conductor and the rate the magnetic field changes.

# %% [markdown]
# #### The eddy current brake shoud apply force on a rotating disk with these dimensions:
# ##### "Outer Diameter: 50mm"
# ##### "Axial Length: 25mm''

# %% [markdown]
# #### The requested torque-speed specifications is:
# ##### "3 Nm at 1620rpm and 1 Nm at 900rpm"

# %% [markdown]
# #### Before we can understand eddy current brakes, we need to understand eddy currents! They're part of the science of electromagnetism: electricity and magnetism aren't two separate things but two sides of the same "coin"—two different aspects of the same underlying phenomenon.
# #### One of the interesting things about eddy currents is that they're not completely random: they flow in a particular way to try to stop whatever it is that causes them. This is an example of another bit of electromagnetism called Lenz's law (it follows on from another law called the conservation of energy, and it's built into the four equations summarizing electromagnetism that were set out by James Clerk Maxwell).
#
# #### Here's an example. Suppose you drop a coin-shaped magnet down the inside of a plastic pipe. It might take a half second to get to the bottom. Now repeat the same experiment with a copper pipe and you'll find your magnet takes much longer (maybe three or four seconds) to make exactly the same journey. Eddy currents are the reason. When the magnet falls through the pipe, you have a magnetic field moving through a stationary conductor (which is exactly the same as a conductor moving through a stationary magnetic field). That creates electric currents in the conductor—eddy currents, in fact. Now we know from the laws of electromagnetism that when a current flows in a conductor, it produces a magnetic field. So the eddy currents generate their own magnetic field. Lenz's law tells us that this magnetic field will try to oppose its cause, which is the falling magnet. So the eddy currents and the second magnetic field produce an upward force on the magnet that tries to stop it from falling. That's why it falls more slowly. In other words, the eddy currents produce a braking effect on the falling magnet.
#
# #### It's because eddy currents always oppose whatever causes them that we can use them as brakes in vehicles, engines, and other machines.
# ### How does an eddy current brake stop something moving?
# #### Suppose we have a railroad train that's actually a huge solid block of copper mounted on wheels. Let's say it's hurtling along at high speed and we want to stop it. We could apply friction brakes to the wheels—or we could stop it with eddy currents. How? What if we put a giant magnet next to the track so the train had to pass nearby. As the copper approached the magnet, eddy currents would be generated (or "induced") inside the copper, which would produce their own magnetic field. Eddy currents in different parts of the copper would try to work in different ways. As the front part of the train approached the magnet, eddy currents in that bit of the copper would try to generate a repulsive magnetic field (to slow down the copper's approach to the magnet). As the front part passed by, slowing down, the currents would start generating an attractive magnetic field that tried to pull the train back again (again, slowing it down). The copper would heat up as the eddy currents swirled inside it, gaining the kinetic energy lost by the train as it slowed down. It might sound like a strange way to stop a train, but it really does work. You'll find the proof of it in many rollercoaster cars, which use magnetic brakes like this, mounted on the side of the track, to slow them down.
# ### Circular brakes
# ####  Like linear eddy current brakes, circular brakes also have one static part and one moving part. They come in two main kinds, according to whether the electromagnet moves or stays still. The simplest ones look like traditional brakes, only with a static electromagnet that applies magnetism and creates eddy currents in a rotating metal disc (instead of simple pressure and friction) that moves through it. (The Shinkansen brakes work like this.) In the other design, the electromagnets move instead: there's a series of electromagnet coils mounted on an outer wheel that spins around (and applies magnetism to) a fixed, central shaft. (Telma frictionless "retarder" brakes, used on many trucks, buses, and coaches, work this way.)
#
# #### How do these things work in practice? Suppose you have a high-speed factory machine that you want to stop without friction. You could mount a metal wheel on one end of the drive shaft and sit it between some electromagnets. Whenever you wanted to stop the machine, you'd just switch on the electromagnets to create eddy currents in the metal wheel that bring it quickly to a halt. Alternatively, you could mount the electromagnet coils on the rotating shaft and have them spin around or inside stationary pieces of metal.
#
# #### With a linear brake, the heat generated by the eddy currents can be dissipated relatively easily: it's easy to see how it would disappear fairly quickly in a brake operating outdoors over a relatively long section of train track. Getting rid of heat is more of an issue with circular brakes, where the eddy currents are constantly circulating in the same piece of metal. For this reason, circular eddy current brakes need some sort of cooling system. Air-cooled brakes have metal meshes, open to the air, which use fan blades to pull cold air through them. Liquid-cooled brakes use cooling fluids to remove heat instead.
# #### Figure 1 shows eddy currents flowıng in a rotating disk due to a magnetic field produced by permanent magnets.

# %%
from IPython.display import Image
Image(filename='Images/figure1.jpg')

# %% [markdown]
# #### Figure 2 and 3 shows the test rig for this research in 3D view which drawn using Ansys Maxwell. They may be changed during design process.

# %%
from IPython.display import Image
Image(filename='Images/fıgure2.jpg')

# %%
from IPython.display import Image
Image(filename='Images/figure3.jpg')

# %% [markdown]
# #### Figure 4 shows how the magnetıc field passes through the disk. it reaches 1.9T in the core and 1.2T whithin the magnet and 0.9 in the airgap. At this situation the disk is constant and therefore we don not observe any circulating current in the copper disk.

# %%
from IPython.display import Image
Image(filename='Images/figure4.jpg')

# %% [markdown]
# #### The disk has been rotated at 900rpm and the current density established on the disk is shown in the figure5.

# %%
from IPython.display import Image
Image(filename='Images/figure5.jpg')

# %% [markdown]
# #### By increasing the rotating speed up to 3000rpm we see that eddu current is increased up to 5,7546e+007

# %%
from IPython.display import Image
Image(filename='images/figure6.jpg')

# %% [markdown]
# #### The flux variation passing the disk is shown in the figure 7.

# %%
from IPython.display import Image
Image(filename='Images/figure7.jpg')

# %% [markdown]
# #### Now we can calculate the rotating torque. As shown in the figure we have a negative torque it shows that it opposes the rotating direction of the disk. But the magnitude of the torque is very small. Thus, we should place more poles around disk.

# %%
from IPython.display import Image
Image(filename='Images/figure8.jpg')

# %% [markdown]
# #### The figure below shows a 6-pole system with same dimensions for cores and disk.

# %%
from IPython.display import Image
Image(filename='Images/figure9.jpg')

# %% [markdown]
# #### Now the disk is rotated at 900rpm and 1620rpm and the toque is calculated:

# %%
from IPython.display import Image
Image(filename='Images/figure10.jpg')

# %%
from IPython.display import Image
Image(filename='Images/figure11.jpg')

# %% [markdown]
# #### For better results the system is designed in a new form with 8 poles and 2 cores as figure12. The airgap is reduced to 2mm in each side of the disk adn the core has been placed in two sides of the magnets.

# %%
from IPython.display import Image
Image(filename='Images/figure12.jpg')

# %% [markdown]
# #### The flux density and established eddy currents can be seen in the figures 13 and 14.

# %%
from IPython.display import Image
Image(filename='Images/figure13.jpg')

# %%
from IPython.display import Image
Image(filename='Images/figure14.jpg')

# %% [markdown]
# #### We see that the amount of flux density is approximately same but because of the increase in the pole numbers the flux variation whithin the disk has been increased and therefore we observe more eddu current.( Compare it with figure 7)
# #### Figure 15 shows the flux variaton in the disk due to the 8-pole magnet.

# %%
from IPython.display import Image
Image(filename='Images/figure15.jpg')

# %% [markdown]
# #### By rotating the disk at 900rpm the below torque is established on the disk.

# %%
from IPython.display import Image
Image(filename='Images/figure16.jpg')

# %% [markdown]
# #### Torque-Speed curve

# %%
from IPython.display import Image
Image(filename='Images/figure17.jpg')

# %% [markdown]
# #### We could reach the requested torque at 900rpm. But the achieved torque at 1600 rpm is about 1.7Nm. We see that the torque has not increased in proportion with speed. It is because of the saturation issue. The system dimensions are too small for the desired results. From this study, it can be concluded that thicker disc will generate high torque. Smaller air-gap will produce high braking torque and give better performance to the electromagnetic braking.
# #### Findings of mentioned parameters from this study are parallel with the theory and will be the guidance to extend this project for any potential application. This system can be used in dewsigning a safety brake for wheelchairs for disabled people preventing the chair from reaching the higher speeds which can be dangerous for a disabled person.
# #### For futher studies analytican approaches can be used to calculated the volume of required magnets and other dimensions in order to have more accurate and practical design.
