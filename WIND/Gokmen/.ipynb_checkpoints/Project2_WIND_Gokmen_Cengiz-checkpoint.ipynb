# %% [markdown]
# # C- Wind Turbine Induction Generator Design

# %% [markdown]
# ## Project Specifications

# %% [markdown]
# In this project, a squirrel cage induction generator for the Northerl Energy's VIRA-250 wind turbine will be designed. The specifications are as follows:
#
# Rated Power: 250 kW
# Rated Wind Speed: 14 m/s
# Rated Turbine Speed: 24.3 rpm
# Gear Ratio: 31.2
# Number of Poles: 8
# Line to line voltage: 400 V
# Frequency: 50 Hz
# Rated Speed: 758 rpm
# Gearbox: (Coupled from wind turbine blade)
# Insulation Class: F

# %%
import math
P_rated=250000; # rated power in W
W_rated=14; # rated wind speed in m/s
n=31.2; # gear ratio 
p=8; # number of poles
pp=p/2; # pole pair of the m/c
V_ll=400; # line-to-line voltage
fs=50; # line frequency
n_rated=758; # rated speed in rpm

# %% [markdown]
# ## Main Dimensions

# %% [markdown]
# The project will start finding stator and rotor dimensions. By using the figure below, we will select a starting point of specific machine constant, Cmech.

# %%
from IPython.display import Image
Image(filename='Cmech.png', width=400, height=400)

# %%
Pmec_2p=(P_rated/1000)/(2*pp); # power per pole in kW
print ('Power per pole is',round(Pmec_2p,2), 'kW.')
# Out:
# Power per pole is 31.25 kW.

# %% [markdown]
# By using the area of p=2-6 and drawing from 31.25 line, I have accepted machine constant as 220 kWs/m3.

# %%
Cmech=220000; # machine constant in Ws/m3

# %%
n_syn=fs/pp; # synhcronous speed in Hz
D2L=P_rated/(Cmech*n_syn); # using formula P=Cmech*D^2*L*nsyn
X=(math.pi/(2*pp))*(pp**(1./3.)); # aspect ratio
D_rotor=(X*D2L)**(1./3.);
L_rotor=X*D_rotor;
print ('Diameter of the rotor is',round(D_rotor,2), 'm.')
print ('Length of the rotor is',round(L_rotor,2), 'm.')
# Out:
# Diameter of the rotor is 0.38 m.
# Length of the rotor is 0.24 m.

# %% [markdown]
# By using the table below, we can set the outer diameter of the rotor.

# %%
from IPython.display import Image
Image(filename='outer_diameter.png', width=400, height=400)

# %%
Do=1.66*D_rotor;
print ('Outer diameter is',round(Do,2), 'm.')
# Out:
# Outer diameter is 0.64 m.

# %% [markdown]
# The air gap of the motor can be calculated by thinking that the motor will operate at heavy-duty.

# %%
δ=1.6*((0.18+(0.006*P_rated**(0.4)))/1000);
print('Airgap is',round(δ,4),'m.')
# Out:
# Airgap is 0.0017 m.
